# %% [markdown]
# ### Analysis of intensity: Using available data, has there a change in intensity since 1852?

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sqlalchemy import create_engine
import psycopg2
from sqlalchemy import create_engine
from config import db_password
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/final_project"
engine = create_engine(db_string)

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Read data from PostgreSQL database table and load into a DataFrame instance

Hurricane_df= pd.read_sql("select * from \"AL_Hurricane\"", db_string);

pd.set_option('display.expand_frame_repr', False);

# Print the DataFrame

#Hurricane_df = Hurricane_df.set_index('ID')
Hurricane_df
# Out:
#            ID                 Name  Year  Month  Day  Time  Latitude  Longitude  Maximum Wind  Minimum Pressure   DB   EX   HU   LO   SD   SS   TD   TS   WV
# 0       11852              UNNAMED  1852      8   26   600      30.2      -88.6           100               961    0    0    1    0    0    0    0    0    0
# 1       11856              UNNAMED  1856      8   10  1800      29.2      -91.1           130               934    0    0    1    0    0    0    0    0    0
# 2       11871              UNNAMED  1871      6    4   700      29.1      -95.1            50               999    0    0    0    0    0    0    0    1    0
# 3       11871              UNNAMED  1871      6    4   600      28.9      -95.0            50               999    0    0    0    0    0    0    0    1    0
# 4       11876              UNNAMED  1876      9    9  1800      40.7      -59.3            80               970    0    0    1    0    0    0    0    0    0
# ...

# %%
# Drop the null rows
Hurricane_df = Hurricane_df.dropna()

# %%
Hurricane_df["ID"] = pd.to_numeric(Hurricane_df["ID"])
Hurricane_df = Hurricane_df.drop(columns=["Name", "Latitude","Longitude"])

# %%
Hurricane_df.dtypes
# Out:
# ID                  int64
# Year                int64
# Month               int64
# Day                 int64
# Time                int64
# Maximum Wind        int64
# Minimum Pressure    int64
#  DB                 int64
#  EX                 int64
#  HU                 int64
#  LO                 int64
#  SD                 int64
#  SS                 int64
#  TD                 int64
#  TS                 int64
#  WV                 int64
# dtype: object

# %%
Hurricane_df = Hurricane_df.values

# %%
X = Hurricane_df["Minimum Pressure","DB","EX","HU","LO","SD","SS","TD","TS","WV"]
y = Hurricane_df["Maximum Wind"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29156\2556387835.py in <module>
# ----> 1 X = Hurricane_df["Minimum Pressure","DB","EX","HU","LO","SD","SS","TD","TS","WV"]
#       2 y = Hurricane_df["Maximum Wind"]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
